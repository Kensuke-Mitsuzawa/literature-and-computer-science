# %% [markdown]
# KNP解析結果から検索のための情報抽出をするノート
#
# date: 2018/08/24

# %%
from knp_utils import knp_job
import pyknp
import json
import codecs

# %%
path_cleaned_text = "../resources/cleaned_text.json"

# %%
story_objects = json.loads(codecs.open(path_cleaned_text, "r", "utf-8").read())
assert isinstance(story_objects, list)

# %%
# KNPの解析は時間かかるので、テキスト量をしぼる
small_size_story_object = story_objects[:1]
knp_utils_input_docs = [
    {
        "text-id": story_object["title"],
        "text": story_object["body"]
    }
    for story_object in small_size_story_object
]

# %%
PATH_JUMAN_COMMAND = "juman"
PATH_KNP_COMMAND = "knp"
KNP_OPTIONS = "-ne-crf -tab"   # 固有名詞発見のためにCRFを呼び出し
result_obj = knp_job.main(seq_input_dict_document=knp_utils_input_docs,
                          n_jobs=-1,
                          is_normalize_text=True,
                          is_get_processed_doc=True,
                          is_split_text=True,
                          juman_command=PATH_JUMAN_COMMAND,
                          knp_command=PATH_KNP_COMMAND,
                          knp_options=KNP_OPTIONS,
                          process_mode="everytime")

# %%
# KNPオブジェクトを取得する
import pyknp
knp_obj = pyknp.KNP()
seq_bunsetsu_obj = [(doc_obj.sentence_index, knp_obj.result(doc_obj.parsed_result)) for doc_obj  in result_obj.seq_document_obj]

# %%
from pyknp.knp.tag import Tag
from typing import Optional

def find_named_entity(knp_tag_obj: Tag)->Optional[str]:
    """KNP解析結果から固有名詞を発見する関数
    
    :param knp_tag_obj: 基本句オブジェクト
    """
    if "NE" in knp_tag_obj.features:
        return knp_tag_obj.features["NE"]

for t_parsed_result in seq_bunsetsu_obj:
    for tag_obj in t_parsed_result[1].tag_list():
        if not find_named_entity(tag_obj) is None:
            print(find_named_entity(tag_obj))
# Out:
# LOCATION:パラオ
# PERSON:繁み
# PERSON:陽
# PERSON:モ・バズ
# LOCATION:パラオ
# LOCATION:ペリリュウ島
# PERCENT:半分
# PERCENT:三分の二
# LOCATION:カヤンガル島
# LOCATION:コロール島
# PERSON:尚
# LOCATION:パラオ
# LOCATION:マングローブ
# PERSON:正覚坊
# LOCATION:呉
# DATE:一日
# PERSON:覚しき男
# DATE:一日
# LOCATION:栄
# LOCATION:呉
# PERSON:充ちていて
# PERSON:悠揚
# PERSON:アア
# LOCATION:オルワンガル島
# LOCATION:オルワンガル島
# DATE:八十年ばかり前
# LOCATION:パラオ

# %%
# TODO 組織・団体, 動物, 植物, 自然物, 人工物-食べ物, 人工物-衣類, 人工物-乗り物, 人工物-金銭, 人工物-その他 で分類したい
from pyknp.juman.morpheme import Morpheme

# カテゴリごとに関数化するよりもforループの方が早い貴がする
def find_person_morph_category(knp_tag_obj: Tag)->Optional[Morpheme]:
    """jumanの形態素カテゴリが「人」になっている基本句を発見する
    
    :return: カテゴリが「人」である形態素
    """
    for m_obj in knp_tag_obj._mrph_list:
        if "カテゴリ:人" in m_obj.fstring:
            return m_obj
        
def find_location_morph_category(knp_tag_obj: Tag)->Optional[Morpheme]:
    """jumanの形態素カテゴリが「場所」になっている基本句を発見する
    
    :return: カテゴリが「場所」である形態素
    """
    for m_obj in knp_tag_obj._mrph_list:
        if "カテゴリ:場所" in m_obj.fstring:
            return m_obj    

        
for t_parsed_result in seq_bunsetsu_obj:
    for tag_obj in t_parsed_result[1].tag_list():
        if not find_person_morph_category(tag_obj) is None:
            print("形態素カテゴリ=人-> " + find_person_morph_category(tag_obj).repname)

        if not find_location_morph_category(tag_obj) is None:
            print("形態素カテゴリ=場所-> " + find_location_morph_category(tag_obj).repname)
# Out:
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 頭/あたま
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 衆人/しゅうじん
# 形態素カテゴリ=人-> 的/まと
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 人/ひと
# 形態素カテゴリ=場所-> 地方/ちほう
# 形態素カテゴリ=人-> 貨幣/かへい
# 形態素カテゴリ=人-> 宝/たから
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 物置/ものおき
# 形態素カテゴリ=場所-> 舎/しゃ
# 形態素カテゴリ=場所-> 片隅/かたすみ
# 形態素カテゴリ=人-> 召し使い/めしつかい
# 形態素カテゴリ=場所-> 家中/いえじゅう
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 怠け者/なまけもの
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 槍/やり
# 形態素カテゴリ=人-> 盥/たらい
# 形態素カテゴリ=人-> 車/くるま
# 形態素カテゴリ=場所-> 午/うま
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 誰/だれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 床/とこ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 家内/かない
# 形態素カテゴリ=場所-> 舎/しゃ
# 形態素カテゴリ=人-> 縄/なわ
# 形態素カテゴリ=場所-> 屋根/やね
# 形態素カテゴリ=人-> 家具/かぐ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 野/の
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=場所-> 田/た
# 形態素カテゴリ=場所-> 外/がい
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=場所-> 西/にし
# 形態素カテゴリ=場所-> 海/うみ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 粗/あら
# 形態素カテゴリ=場所-> 床/とこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 地方/ちほう
# 形態素カテゴリ=場所-> 北/きた
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 南/みなみ
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 田/た
# 形態素カテゴリ=場所-> 林/はやし
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 台所/だいどころ
# 形態素カテゴリ=人-> 皿/さら
# 形態素カテゴリ=場所-> 天井/てんじょう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 脂/あぶら
# 形態素カテゴリ=人-> 胎児/たいじ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 祖先/そせん
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 敵/てき
# 形態素カテゴリ=人-> 大将/たいしょう
# 形態素カテゴリ=人-> 槍/やり
# 形態素カテゴリ=場所-> 蔵/くら
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 浜辺/はまべ
# 形態素カテゴリ=人-> 卵/たまご
# 形態素カテゴリ=場所-> 環礁/かんしょう
# 形態素カテゴリ=場所-> 外/がい
# 形態素カテゴリ=場所-> 梁/はり
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 中央/ちゅうおう
# 形態素カテゴリ=場所-> 屋根/やね
# 形態素カテゴリ=場所-> 場/ば
# 形態素カテゴリ=人-> 島民/とうみん
# 形態素カテゴリ=人-> 一同/いちどう
# 形態素カテゴリ=人-> 種子/しゅし
# 形態素カテゴリ=人-> 頭/あたま
# 形態素カテゴリ=人-> 船/ふね
# 形態素カテゴリ=人-> 者/しゃ
# 形態素カテゴリ=人-> 金/かね
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=場所-> 表向き/おもてむき
# 形態素カテゴリ=人-> 人/にん
# 形態素カテゴリ=人-> 近親/きんしん
# 形態素カテゴリ=場所-> 範囲/はんい
# 形態素カテゴリ=人-> 者/しゃ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 樽/たる
# 形態素カテゴリ=人-> 者/もの
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 海/うみ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 船/ふね
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 水中/すいちゅう
# 形態素カテゴリ=人-> 船/ふね
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 水中/すいちゅう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 従者/じゅうしゃ
# 形態素カテゴリ=人-> 棒/ぼう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 左/ひだり
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 奴/やつ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 南方/なんぽう
# 形態素カテゴリ=場所-> 島/とう
# 形態素カテゴリ=人-> 人間/にんげん
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=人-> 事/こと
# 形態素カテゴリ=場所-> 事/こと
# 形態素カテゴリ=人-> 主人公/しゅじんこう
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 空/から
# 形態素カテゴリ=人-> 汁/しる
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 人間/にんげん
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=人-> 婦人/ふじん
# 形態素カテゴリ=場所-> 田/た
# 形態素カテゴリ=場所-> 海/うみ
# 形態素カテゴリ=場所-> 空/から
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 人間/にんげん
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=場所-> 丘/おか
# 形態素カテゴリ=人-> 人間/にんげん
# 形態素カテゴリ=人-> 俺/おれ
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=場所-> 畑/はたけ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 隣り/となり
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 神々/かみがみ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 神々/かみがみ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 供物/くもつ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 食物/しょくもつ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 神/かみ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 母屋/おもや
# 形態素カテゴリ=場所-> 中央/ちゅうおう
# 形態素カテゴリ=人-> 家長/かちょう
# 形態素カテゴリ=人-> 人々/ひとびと
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 食事/しょくじ
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=人-> 大勢/おおぜい
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 食卓/しょくたく
# 形態素カテゴリ=人-> 卵/たまご
# 形態素カテゴリ=場所-> 山/さん
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 屋根/やね
# 形態素カテゴリ=人-> 柱/ちゅう
# 形態素カテゴリ=場所-> 柱/ちゅう
# 形態素カテゴリ=人-> 物置/ものおき
# 形態素カテゴリ=場所-> 舎/しゃ
# 形態素カテゴリ=場所-> 隅/すみ
# 形態素カテゴリ=人-> 家人/かじん
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 食卓/しょくたく
# 形態素カテゴリ=人-> 肴/さかな
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=人-> 美人/びじん
# 形態素カテゴリ=人-> 茣蓙/ござ
# 形態素カテゴリ=場所-> 舎/しゃ
# 形態素カテゴリ=人-> 食物/しょくもつ
# 形態素カテゴリ=人-> 粗/あら
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 板/いた
# 形態素カテゴリ=人-> 御馳走/ごちそう
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=人-> 妻/つま
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=人-> 島民/とうみん
# 形態素カテゴリ=人-> 船/ふね
# 形態素カテゴリ=場所-> 庫/こ
# 形態素カテゴリ=人-> 司祭/しさい
# 形態素カテゴリ=場所-> 神前/しんぜん
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 島民/とうみん
# 形態素カテゴリ=人-> 英雄/えいゆう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 人/り
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 船/ふね
# 形態素カテゴリ=場所-> 途/と
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=場所-> 水中/すいちゅう
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 辛/しん
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 柱/ちゅう
# 形態素カテゴリ=場所-> 柱/ちゅう
# 形態素カテゴリ=場所-> 寝床/ねどこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 肥/こえ
# 形態素カテゴリ=場所-> 空/から
# 形態素カテゴリ=人-> 者/しゃ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=場所-> 卯/う
# 形態素カテゴリ=場所-> 一方/いっぽう
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=人-> 富/とみ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 縄/なわ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 車/くるま
# 形態素カテゴリ=人-> 食事/しょくじ
# 形態素カテゴリ=人-> 粗/あら
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 母屋/おもや
# 形態素カテゴリ=場所-> 中央/ちゅうおう
# 形態素カテゴリ=人-> 茣蓙/ござ
# 形態素カテゴリ=場所-> 卯/う
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 脂/あぶら
# 形態素カテゴリ=人-> 粗/あら
# 形態素カテゴリ=人-> 誰/だれ
# 形態素カテゴリ=場所-> 外/がい
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 空/から
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 所/ところ
# 形態素カテゴリ=場所-> 目の前/めのまえ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=場所-> 空/から
# 形態素カテゴリ=人-> 者/しゃ
# 形態素カテゴリ=人-> 肥/こえ
# 形態素カテゴリ=場所-> 利/り
# 形態素カテゴリ=場所-> 地底/ちてい
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 相手/あいて
# 形態素カテゴリ=人-> 者/しゃ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 頭/あたま
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=人-> 者/もの
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 女/おんな
# 形態素カテゴリ=場所-> 天国/てんごく
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=人-> 長老/ちょうろう
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=場所-> 余地/よち
# 形態素カテゴリ=人-> 彼/かれ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=人-> 己/おのれ
# 形態素カテゴリ=人-> 自分/じぶん
# 形態素カテゴリ=人-> 粗/あら
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 干潟/ひがた
# 形態素カテゴリ=場所-> 海/うみ
# 形態素カテゴリ=人-> 男/おとこ
# 形態素カテゴリ=場所-> 世界/せかい
# 形態素カテゴリ=人-> 富/とみ
# 形態素カテゴリ=人-> 主人/あるじ
# 形態素カテゴリ=場所-> 下/した
# 形態素カテゴリ=人-> 僕/ぼく
# 形態素カテゴリ=場所-> 右/みぎ
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 島/しま
# 形態素カテゴリ=場所-> 前/まえ
# 形態素カテゴリ=人-> 住民/じゅうみん
# 形態素カテゴリ=場所-> 海底/かいてい
# 形態素カテゴリ=人-> 男/おとこ

# %%
from typing import Tuple, Dict
from pyknp.knp.pas import Pas

def find_predicate_relation(knp_tag_obj: Tag)->Optional[Tuple[Tag, Pas]]:
    """KNPの解析結果から述語と格を発見する関数

    :param knp_tag_obj: 基本句オブジェクト
    :return: タプル。タプルは基本句オブジェクトと述語項オブジェクトを持つ。そもそも述語でない場合はNone。
    """
    if knp_tag_obj.features.pas is None:
        return None
    else:
        return (knp_tag_obj, knp_tag_obj.features.pas)
        
for t_parsed_result in seq_bunsetsu_obj:
    for tag_obj in t_parsed_result[1].tag_list():
        if  find_predicate_relation(tag_obj) is not None:
            t_predicate_argument = find_predicate_relation(tag_obj)
            # ユーザーに見せる正規化代表表記
            repname = t_predicate_argument[0].repname
            # 述語を一意に識別するid
            predicate_id = t_predicate_argument[1].cfid
            # 格対応オブジェクトを得る
            dict_arguments = t_predicate_argument[1].arguments
            # 表示用の文字列
            p_case_name_relation = ""
            for case_name, seq_arg_obj in dict_arguments.items():
                assert isinstance(seq_arg_obj, list)
                seq_arg_repname = [a_obj.rep for a_obj in seq_arg_obj]
                # TODO Argumentは基本句単位でしか出力されないので、意味がある句に拡張したければ、拡張ルールを書くこと
                seq_arg_tid = [a_obj.tid for a_obj in seq_arg_obj]
                # 表示用の文字列
                p_case_name_relation += "格タイプ={}: 格表層={} / ".format(case_name, ", ".join(seq_arg_repname))
                
            print("格フレームid -> {} {}".format(predicate_id, p_case_name_relation))
# Out:
# 格フレームid -> 極める/きわめる:動0 格タイプ=ガ: 格表層=人 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 居る/いる:動12 格タイプ=ガ: 格表層=男 / 格タイプ=時間: 格表層=昔 / 格タイプ=ニ: 格表層=島 /
# 格フレームid -> 数える/かぞえる:動1 格タイプ=ヲ: 格表層=年齢 /
# 格フレームid -> 不自然だ/ふしぜんだ:形3 格タイプ=ガ: 格表層=習慣 /
# 格フレームid -> 無い/ない:形47 格タイプ=ガ: 格表層=習慣 / 格タイプ=ニ: 格表層=辺 /
# 格フレームid -> 言える/いえる:動1 格タイプ=ガ: 格表層=こと / 格タイプ=修飾: 格表層=ハッキリ /
# 格フレームid -> 若い/わかい:形9 格タイプ=ガ: 格表層=こと / 格タイプ=修飾: 格表層=余り /
# 格フレームid -> 確かだ/たしかだ:形4 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 余る/あまる:動4 格タイプ=ガ: 格表層=毛 /
# 格フレームid -> 縮れる/ちぢれる:動
# 格フレームid -> 潰れる/つぶれる:動0 格タイプ=ガ: 格表層=頭 /
# 格フレームid -> 成る/なる~テ形+いる/いる:動2 格タイプ=ガ: 格表層=貌 / 格タイプ=ト: 格表層=的 /
# 格フレームid -> 薄い/うすい:形3 格タイプ=ガ: 格表層=脣 /
# 格フレームid -> 見事だ/みごとだ:形12 格タイプ=ガ: 格表層=黒檀 /
# 格フレームid -> 様/よう:判1 格タイプ=ガ: 格表層=艶 /
# 格フレームid -> 無い/ない:形182 格タイプ=ガ: 格表層=艶 / 格タイプ=外の関係: 格表層=こと / 格タイプ=ニ: 格表層=顔色 /
# 格フレームid -> 甚だしい/はなはだしい:形1 格タイプ=ガ: 格表層=もの / 格タイプ=修飾: 格表層=一層 /
# 格フレームid -> する/する~テ形+いる/いる:動2 格タイプ=ガ: 格表層=こと / 格タイプ=ヲ: 格表層=さ / 格タイプ=ニ: 格表層=もの / 格タイプ=修飾: 格表層=おまけに /
# 格フレームid -> 人/ひと:判1 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=恐らく /
# 格フレームid -> 称する/しょうする:動2 格タイプ=ガ: 格表層=勾玉 /
# 格フレームid -> 様/よう:判1 格タイプ=ガ: 格表層=もの /
# 格フレームid -> 貨幣/かへい:判0 格タイプ=ガ: 格表層=もの /
# 格フレームid -> 宝/たから:判0
# 格フレームid -> 持つ/もつ~テ形+いる/いる:動4 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=勿論 /
# 格フレームid -> 持つ/もつ~テ形+いる/いる:動4 格タイプ=ガ: 格表層=ウドウド / 格タイプ=外の関係: 格表層=位 /
# 格フレームid -> くらい/くらい:判0
# 格フレームid -> 浮く/うく:動11 格タイプ=ガ: 格表層=購 / 格タイプ=修飾: 格表層=始めて / 格タイプ=ニヨル: 格表層=之 /
# 格フレームid -> 出来る/できる:動1 格タイプ=ガ: 格表層=妻 /
# 格フレームid -> 持てる/もてる:動7 格タイプ=ガ: 格表層=訳 / 格タイプ=ヲ: 格表層=妻 /
# 格フレームid -> 無い/ない:形2 格タイプ=ガ: 格表層=訳 /
# 格フレームid -> 断つ/たつ:動12 格タイプ=ガ: 格表層=独り /
# 格フレームid -> 住む/すむ:動12 格タイプ=ニ: 格表層=片隅 /
# 格フレームid -> 卑しい/いやしい:形6 格タイプ=ガ: 格表層=召使 /
# 格フレームid -> する/する:動1 格タイプ=ト: 格表層=召使 /
# 格フレームid -> 仕える/つかえる~テ形+いる/いる:動0 格タイプ=修飾: 格表層=独り /
# 格フレームid -> 卑しい/いやしい:形6 格タイプ=ガ: 格表層=勤め /
# 格フレームid -> 負う/おう+す/す+れる/れる:動2 格タイプ=ガ: 格表層=勤め / 格タイプ=ニ: 格表層=上 /
# 格フレームid -> 揃う/そろう:動3 格タイプ=ガ: 格表層=怠け者 / 格タイプ=外の関係: 格表層=島 /
# 格フレームid -> 怠ける/なまける:動2 格タイプ=ガ: 格表層=暇 /
# 格フレームid -> 無い/ない:形1 格タイプ=ガ: 格表層=暇 / 格タイプ=デ: 格表層=中 / 格タイプ=ガ２: 格表層=人 /
# 格フレームid -> 早い/はやい:形1 格タイプ=ヨリ: 格表層=鳥 /
# 格フレームid -> 起きる/おきる:動1 格タイプ=修飾: 格表層=早く / 格タイプ=時間: 格表層=朝 / 格タイプ=ニ: 格表層=み /
# 格フレームid -> 出掛ける/でかける:動13 格タイプ=時間: 格表層=朝 / 格タイプ=ニ: 格表層=漁 /
# 格フレームid -> 突つく/つつく:動1 格タイプ=ヲ: 格表層=蛸 / 格タイプ=デ: 格表層=槍 /
# 格フレームid -> 吸い付く/すいつく:動4 格タイプ=ガ: 格表層=損 / 格タイプ=ニ: 格表層=胸, 腹 /
# 格フレームid -> 腫れる/はれる:動0 格タイプ=修飾: 格表層=中 /
# 格フレームid -> 追う/おう+れる/れる:動1 格タイプ=ニ: 格表層=タマカイ /
# 格フレームid -> 逃げる/にげる:動32 格タイプ=修飾: 格表層=命からがら / 格タイプ=ニ: 格表層=独木舟 /
# 格フレームid -> 有る/ある:動169 格タイプ=ガ: 格表層=盥 / 格タイプ=外の関係: 格表層=貝 /
# 格フレームid -> 挟む/はさむ+れる/れる:動2 格タイプ=ヲ: 格表層=足 / 格タイプ=ニ: 格表層=貝 /
# 格フレームid -> 損/損:判
# 格フレームid -> 成る/なる:動1 格タイプ=ニ: 格表層=午 /
# 格フレームid -> 取る/とる:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=午睡 / 格タイプ=修飾: 格表層=上 / 格タイプ=外の関係: 格表層=時 /
# 格フレームid -> 清掃/せいそう:名1
# 格フレームid -> 建築/けんちく:名1
# 格フレームid -> 製作/せいさく:名1
# 格フレームid -> 回る/まわる:動4 格タイプ=ガ: 格表層=目 / 格タイプ=外の関係: 格表層=程 / 格タイプ=ニ: 格表層=製作 /
# 格フレームid -> 忙しい/いそがしい:形1 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=程 / 格タイプ=時間: 格表層=時 / 格タイプ=ニ: 格表層=清掃, 建築 /
# 格フレームid -> 濡れる/ぬれる~テ形+いる/いる:動2 格タイプ=ガ: 格表層=皮膚 / 格タイプ=修飾: 格表層=絶えず / 格タイプ=デ: 格表層=汗 / 格タイプ=ニ: 格表層=様 /
# 格フレームid -> 仕事/しごと:名1
# 格フレームid -> 極める/きわめる:動20 格タイプ=ガ: 格表層=田 /
# 格フレームid -> 働く/はたらく:動6 格タイプ=ガ: 格表層=男 / 格タイプ=ヲ: 格表層=外 / 格タイプ=デ: 格表層=人 / 格タイプ=時間: 格表層=昔 / 格タイプ=カラ: 格表層=何 /
# 格フレームid -> 入る/はいる:動19 格タイプ=ガ: 格表層=陽 / 格タイプ=ニ: 格表層=海 /
# 格フレームid -> 飛ぶ/とぶ:動38 格タイプ=ガ: 格表層=蝙蝠 / 格タイプ=外の関係: 格表層=頃 /
# 格フレームid -> 鳴る/なる:動1 格タイプ=時間: 格表層=頃 / 格タイプ=ニ: 格表層=梢 /
# 格フレームid -> 漸/漸:形
# 格フレームid -> あてがう/あてがう+れる/れる:動8 格タイプ=ヲ: 格表層=芋 / 格タイプ=ニ: 格表層=猫 /
# 格フレームid -> ありつく/ありつく:動2 格タイプ=ガ: 格表層=男 / 格タイプ=ニ: 格表層=尻尾, あら /
# 格フレームid -> 疲れる/つかれる+果てる/はてる:動8 格タイプ=ガ: 格表層=身体 /
# 格フレームid -> 堅い/かたい:形24 格タイプ=ガ: 格表層=竹 /
# 格フレームid -> 横たえる/よこたえる:動1 格タイプ=ヲ: 格表層=身体 / 格タイプ=ニ: 格表層=上 /
# 格フレームid -> 眠る/ねむる:動16 格タイプ=カラ: 格表層=それ /
# 格フレームid -> 言う/いう:動1 格タイプ=デ: 格表層=語 /
# 格フレームid -> 成る/なる:動1 格タイプ=ニ: 格表層=バズ, 石 /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=主人 / 格タイプ=外の関係: 格表層=島 /
# 格フレームid -> 北/きた:判0
# 格フレームid -> 遠い/とおい:形2 格タイプ=ガ: 格表層=南 /
# 格フレームid -> 至る/いたる:動12 格タイプ=ガ: 格表層=北 / 格タイプ=ニ: 格表層=島 /
# 格フレームid -> 物持ち/ものもち:判0 格タイプ=ガ: 格表層=長老 /
# 格フレームid -> 属する/ぞくする:動1 格タイプ=ガ: 格表層=半分, 三分の二 / 格タイプ=ニ: 格表層=もの /
# 格フレームid -> 高い/たかい:形4 格タイプ=ガ: 格表層=皿 / 格タイプ=ガ２: 格表層=迄 /
# 格フレームid -> 上げる/あげる+られる/られる~テ形+いる/いる:動3 格タイプ=ガ: 格表層=積 / 格タイプ=ニ: 格表層=台所 /
# 格フレームid -> 美食/びしょく:名1
# 格フレームid -> 射る/いる~テ形+いる/いる:動1 格タイプ=ガ: 格表層=※ / 格タイプ=ヲ: 格表層=彼 / 格タイプ=時間: 格表層=毎日 / 格タイプ=ニ: 格表層=美食 /
# 格フレームid -> 脂ぎる/あぶらぎる:動1
# 格フレームid -> 孕む/はらむ:動0
# 格フレームid -> 豚/ぶた:判0
# 格フレームid -> 似る/にる:動0
# 格フレームid -> 膨らむ/ふくらむ~テ形+いる/いる:動3 格タイプ=ガ: 格表層=腹 / 格タイプ=修飾: 格表層=豚 /
# 格フレームid -> 討つ/うつ:動2 格タイプ=ガ: 格表層=人 / 格タイプ=ヲ: 格表層=島 / 格タイプ=時間: 格表層=昔 / 格タイプ=ニ: 格表層=家 / 格タイプ=外の関係: 格表層=時 /
# 格フレームid -> 仕留める/しとめる:動4 格タイプ=ヲ: 格表層=大将 / 格タイプ=ニ: 格表層=突き /
# 格フレームid -> 蔵/くら:動4 格タイプ=ガ: 格表層=槍 /
# 格フレームid -> 所有/しょゆう:動15 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=貨 /
# 格フレームid -> 生み付ける/うみつける:動1 格タイプ=ガ: 格表層=玳瑁 / 格タイプ=ヲ: 格表層=卵 / 格タイプ=デ: 格表層=浜辺 / 格タイプ=修飾: 格表層=一度に /
# 格フレームid -> 多い/おおい:形53 格タイプ=ガ: 格表層=貨 / 格タイプ=修飾: 格表層=数 /
# 格フレームid -> 尊い/とうとい:形6 格タイプ=ガ: 格表層=珠 /
# 格フレームid -> 至る/いたる:動1 格タイプ=ニ: 格表層=珠 /
# 格フレームid -> 梁/はり:動0 格タイプ=ガ: 格表層=鮫 /
# 格フレームid -> 見る/みる:動8 格タイプ=修飾: 格表層=一目 / 格タイプ=デ: 格表層=鮫 / 格タイプ=ニ: 格表層=外 /
# 格フレームid -> 退散/たいさん:動1 格タイプ=外の関係: 格表層=程 / 格タイプ=デ: 格表層=中 /
# 格フレームid -> 備える/そなえる~テ形+いる/いる:動2 格タイプ=ヲ: 格表層=威力 /
# 格フレームid -> する/する:動1 格タイプ=ト: 格表層=然 /
# 格フレームid -> 立/立:動0
# 格フレームid -> 飾る/かざる+れる/れる:動1 格タイプ=デ: 格表層=模様 /
# 格フレームid -> 反る/そる:動0
# 格フレームid -> 造る/つくる:動5 格タイプ=ヲ: 格表層=場 / 格タイプ=ニ: 格表層=中央 /
# 格フレームid -> 自慢/じまん:名1
# 格フレームid -> 種子/しゅし:判0 格タイプ=ガ: 格表層=頭 /
# 格フレームid -> 赤/あか:判8 格タイプ=ガ: 格表層=舟 /
# 格フレームid -> 作る/つくる:動35 格タイプ=ガ: 格表層=の / 格タイプ=ヲ: 格表層=舟 /
# 格フレームid -> 有る/ある:動4 格タイプ=ガ: 格表層=の / 格タイプ=デ: 格表層=権勢, 力 / 格タイプ=時間: 格表層=今 /
# 格フレームid -> 人/にん:判22 格タイプ=ガ: 格表層=妻 / 格タイプ=ガ２: 格表層=表向き /
# 格フレームid -> 許す/ゆるす:動1 格タイプ=ガ: 格表層=禁忌 / 格タイプ=外の関係: 格表層=範囲 /
# 格フレームid -> 居る/いる:動17 格タイプ=ガ: 格表層=於 / 格タイプ=ニ: 格表層=範囲 /
# 格フレームid -> 無限だ/むげんだ:形1 格タイプ=ガ: 格表層=数 / 格タイプ=修飾: 格表層=実際 /
# 格フレームid -> 言う/いう:動1 格タイプ=ト: 格表層=無限 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=許さ /
# 格フレームid -> 醜い/みにくい:形5 格タイプ=ガ: 格表層=許さ /
# 格フレームid -> 卑しい/いやしい:形8 格タイプ=ガ: 格表層=身分 / 格タイプ=修飾: 格表層=独り / 格タイプ=ガ２: 格表層=者 /
# 格フレームid -> 直接だ/ちょくせつだ:形13 格タイプ=ガ: 格表層=主人 /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=主人 / 格タイプ=時間: 格表層=長老 /
# 格フレームid -> ルバック/ルバック:動0 格タイプ=ガ: 格表層=二, 三 /
# 格フレームid -> 通る/とおる:動2 格タイプ=ヲ: 格表層=前 / 格タイプ=外の関係: 格表層=時 /
# 格フレームid -> 立つ/たつ:動0
# 格フレームid -> 歩く/あるく:動17 格タイプ=外の関係: 格表層=こと / 格タイプ=デ: 格表層=時 /
# 格フレームid -> 許す/ゆるす+れる/れる:動39 格タイプ=ガ: 格表層=者 / 格タイプ=ヲ: 格表層=こと / 格タイプ=ガ２: 格表層=長老 /
# 格フレームid -> 行/ぎょう:動
# 格フレームid -> 過ぎる/すぎる:動0 格タイプ=修飾: 格表層=必ず /
# 格フレームid -> 乗る/のる:動12 格タイプ=ニ: 格表層=独木舟 /
# 格フレームid -> 出る/でる~テ形+いる/いる:動35 格タイプ=外の関係: 格表層=時 / 格タイプ=ニ: 格表層=海 /
# 格フレームid -> 近付く/ちかづく:動10 格タイプ=ガ: 格表層=舟 / 格タイプ=時間: 格表層=時 /
# 格フレームid -> 跳ぶ/とぶ:動12 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=もし / 格タイプ=ニ: 格表層=水中 / 格タイプ=カラ: 格表層=上 /
# 格フレームid -> 挨拶/あいさつ:動2 格タイプ=ガ: 格表層=無礼 / 格タイプ=カラ: 格表層=上 /
# 格フレームid -> 無礼/ぶれいa:名1
# 格フレームid -> 許す/ゆるす+れる/れる:動5 格タイプ=ガ: 格表層=無礼 / 格タイプ=修飾: 格表層=絶対 /
# 格フレームid -> ぶつかる/ぶつかる:動0 格タイプ=修飾: 格表層=場合 /
# 格フレームid -> 謹慎/きんしん:名1
# 格フレームid -> 飛ぶ/とぶ+込む/こむ:動8 格タイプ=ガ: 格表層=彼 / 格タイプ=デ: 格表層=謹しん / 格タイプ=ニ: 格表層=水中 /
# 格フレームid -> 入る/はいる:動28 格タイプ=ガ: 格表層=姿 / 格タイプ=ニ: 格表層=目 /
# 格フレームid -> 躊躇/ちゅうちょ:動10 格タイプ=ガ: 格表層=彼 /
# 格フレームid -> 見る/みる:動80 格タイプ=ガ: 格表層=長老 / 格タイプ=ヲ: 格表層=の /
# 格フレームid -> 怒る/いかる:動
# 格フレームid -> 投げる/なげる+付ける/つける:動1 格タイプ=ガ: 格表層=従者 / 格タイプ=ヲ: 格表層=切 /
# 格フレームid -> 桁/けた:名1
# 格フレームid -> 得る/える:動8 格タイプ=ヲ: 格表層=む /
# 格フレームid -> 泳ぐ/およぐ~テ形+いる/いる:動2 格タイプ=ガ: 格表層=鱶 / 格タイプ=外の関係: 格表層=水 /
# 格フレームid -> 跳ぶ/とぶ:動10 格タイプ=ガ: 格表層=彼 / 格タイプ=ニ: 格表層=中 /
# 格フレームid -> 大きい/おおきい:形16 格タイプ=ガ: 格表層=鱶 / 格タイプ=修飾: 格表層=尺 / 格タイプ=ガ２: 格表層=奴 /
# 格フレームid -> 奴/やつ:判0
# 格フレームid -> 切る/きる+れる/れる:動1 格タイプ=ガ: 格表層=喰 / 格タイプ=ヲ: 格表層=指 /
# 格フレームid -> 済む/すむ:動25 格タイプ=ガ: 格表層=彼 / 格タイプ=デ: 格表層=切ら /
# 格フレームid -> 離れる/はなれる:動20 格タイプ=ガ: 格表層=文化 / 格タイプ=ニ: 格表層=南方 / 格タイプ=カラ: 格表層=島 /
# 格フレームid -> 白い/しろい:形16 格タイプ=ガ: 格表層=皮膚 / 格タイプ=ガ２: 格表層=共 /
# 格フレームid -> 伝える/つたえる:動15 格タイプ=ガ: 格表層=共 / 格タイプ=修飾: 格表層=既に / 格タイプ=ニ: 格表層=島 /
# 格フレームid -> 悪い/わるい:形33 格タイプ=ガ: 格表層=病 /
# 格フレームid -> 侵入/しんにゅう:動1 格タイプ=ガ: 格表層=病 /
# 格フレームid -> 有る/ある:動61 格タイプ=修飾: 格表層=つ / 格タイプ=ニ: 格表層=病 /
# 格フレームid -> 神聖だ/しんせいだ:形1 格タイプ=ガ: 格表層=天与 /
# 格フレームid -> 妨げる/さまたげる:動1 格タイプ=ガ: 格表層=病 / 格タイプ=ヲ: 格表層=秘事 / 格タイプ=修飾: 格表層=つ /
# 格フレームid -> 怪しい/あやしい:形6 格タイプ=ガ: 格表層=病 /
# 格フレームid -> 病/びょう:判
# 格フレームid -> 係る/かかる:動3 格タイプ=外の関係: 格表層=時 / 格タイプ=ニ: 格表層=之 /
# 格フレームid -> 呼ぶ/よぶ+れる/れる:動4 格タイプ=ガ: 格表層=男 / 格タイプ=時間: 格表層=時 / 格タイプ=ト: 格表層=病 /
# 格フレームid -> 成る/なる:動43 格タイプ=ガ: 格表層=女 / 格タイプ=外の関係: 格表層=場合 /
# 格フレームid -> 病/びょう:判
# 格フレームid -> 言う/いう+れる/れる:動2 格タイプ=デ: 格表層=コロール / 格タイプ=ト: 格表層=病 /
# 格フレームid -> 兆候/ちょうこう:形
# 格フレームid -> 容易だ/よういだ:形0
# 格フレームid -> 認める/みとめる+がたい/がたい:動1 格タイプ=ガ: 格表層=病気 / 格タイプ=修飾: 格表層=容易に /
# 格フレームid -> 病気/びょうき:判2 格タイプ=ガ: 格表層=方 / 格タイプ=修飾: 格表層=極めて /
# 格フレームid -> 軽い/かるい:形26 格タイプ=ガ: 格表層=咳 /
# 格フレームid -> 出る/でる:動4 格タイプ=ガ: 格表層=咳 /
# 格フレームid -> 疲れる/つかれる:動40 格タイプ=ガ: 格表層=顔色 /
# 格フレームid -> 痩せ衰える/やせおとろえる:動
# 格フレームid -> 死ぬ/しぬ:動0 格タイプ=修飾: 格表層=何時の間にか /
# 格フレームid -> 喀/喀:形
# 格フレームid -> 無い/ない:形1
# 格フレームid -> 話/はなし:名0
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=主人公 / 格タイプ=時間: 格表層=男 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 罹る/かかる~テ形+いる/いる:動1 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=どうやら / 格タイプ=ニ: 格表層=病気 /
# 格フレームid -> する/する:動36 格タイプ=ヲ: 格表層=咳 / 格タイプ=修飾: 格表層=絶えず /
# 格フレームid -> 疲れる/つかれる:動0
# 格フレームid -> 擂り潰す/すりつぶす:動1 格タイプ=ヲ: 格表層=芽 /
# 格フレームid -> 飲む/のむ:動11 格タイプ=ヲ: 格表層=汁 /
# 格フレームid -> 煎じる/せんじる:動3 格タイプ=ヲ: 格表層=根 /
# 格フレームid -> 飲む/のむ:動0
# 格フレームid -> 無い/ない:形13 格タイプ=ガ: 格表層=効き目 / 格タイプ=修飾: 格表層=一向に /
# 格フレームid -> 付く/つく:動12 格タイプ=ガ: 格表層=気 / 格タイプ=ヲ: 格表層=主人 / 格タイプ=ニ: 格表層=之 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=病気 /
# 格フレームid -> 成る/なる:動1 格タイプ=ガ: 格表層=男 / 格タイプ=外の関係: 格表層=こと / 格タイプ=ニ: 格表層=病気 /
# 格フレームid -> 相応しい/ふさわしい:形0 格タイプ=修飾: 格表層=大変 /
# 格フレームid -> 考える/かんがえる:動47 格タイプ=ヲ: 格表層=こと / 格タイプ=ト: 格表層=ふさわしい /
# 格フレームid -> 仕事/しごと:名1
# 格フレームid -> 増える/ふえる:動10 格タイプ=ガ: 格表層=仕事 / 格タイプ=修飾: 格表層=益々 / 格タイプ=デ: 格表層=それ /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 賢い/かしこい:形2 格タイプ=ガ: 格表層=人間 / 格タイプ=修飾: 格表層=しかし /
# 格フレームid -> 人間/にんげん:判12 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 辛い/からい:形3 格タイプ=ガ: 格表層=己 / 格タイプ=ヲ: 格表層=運命 / 格タイプ=修飾: 格表層=格別 /
# 格フレームid -> 思う/おもう:動1 格タイプ=ガ: 格表層=辛い /
# 格フレームid -> 刻/刻:名1
# 格フレームid -> 見る/みる:動143 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 聴く/きく:動1 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 呼吸/こきゅう:動1 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 禁じる/きんじる:動1 格タイプ=ガ: 格表層=こと, こと, こと / 格タイプ=ヲ: 格表層=迄 /
# 格フレームid -> 有り難い/ありがたい:形1 格タイプ=ガ: 格表層=主人 / 格タイプ=ニ: 格表層=尚, 自分 /
# 格フレームid -> 思う/おもう~テ形+いる/いる:動1 格タイプ=ト: 格表層=有難い /
# 格フレームid -> 課する/かする:動8 格タイプ=ガ: 格表層=仕事 / 格タイプ=ニ: 格表層=自分 /
# 格フレームid -> 仕事/しごと:名1
# 格フレームid -> 神聖だ/しんせいだ:形1 格タイプ=ガ: 格表層=天職 /
# 格フレームid -> 足る/たる:動2 格タイプ=ガ: 格表層=天職 / 格タイプ=修飾: 格表層=如何に / 格タイプ=ト: 格表層=多く / 格タイプ=外の関係: 格表層=耕作 /
# 格フレームid -> 耕作/こうさく:名1
# 格フレームid -> 除外/じょがい+する/する+れる/れる~テ形+いる/いる:動3 格タイプ=ガ: 格表層=耕作 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 有り難い/ありがたい:形0
# 格フレームid -> 思う/おもう:動1 格タイプ=ガ: 格表層=仕事 / 格タイプ=修飾: 格表層=有難く /
# 格フレームid -> 考える/かんがえる:動1 格タイプ=ト: 格表層=思おう /
# 格フレームid -> 居る/いる:動26 格タイプ=ガ: 格表層=鱶 / 格タイプ=外の関係: 格表層=海 /
# 格フレームid -> 跳ぶ/とぶ:動1 格タイプ=ニ: 格表層=海 /
# 格フレームid -> 失う/うしなう:動16 格タイプ=ヲ: 格表層=指 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 不幸/ふこうa:判0 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 切る/きる+れる/れる:動11 格タイプ=ガ: 格表層=喰 / 格タイプ=ヲ: 格表層=脚 / 格タイプ=修飾: 格表層=それ / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 感謝/かんしゃ:動10 格タイプ=ヲ: 格表層=こと /
# 格フレームid -> 出る/でる:動4 格タイプ=ガ: 格表層=咳 / 格タイプ=外の関係: 格表層=病 /
# 格フレームid -> 罹る/かかる:動2 格タイプ=外の関係: 格表層=こと / 格タイプ=ニ: 格表層=病 /
# 格フレームid -> 罹る/かかる:動1 格タイプ=ガ: 格表層=迄 / 格タイプ=時間: 格表層=人間 / 格タイプ=ニ: 格表層=病 /
# 格フレームid -> 有る/ある:動1 格タイプ=ガ: 格表層=こと, 人間 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 思う/おもう:動1
# 格フレームid -> 少ない/すくない:形0
# 格フレームid -> 免れる/まぬがれる:動3 格タイプ=ガ: 格表層=病 / 格タイプ=ヲ: 格表層=こと / 格タイプ=ト: 格表層=少く /
# 格フレームid -> 乾く/かわく:動4 格タイプ=ガ: 格表層=頭髪 / 格タイプ=外の関係: 格表層=様 /
# 格フレームid -> 縮れる/ちぢれる~テ形+いる/いる:動1 格タイプ=外の関係: 格表層=こと / 格タイプ=ニ: 格表層=様 /
# 格フレームid -> 明らかだ/あきらかだ:形0
# 格フレームid -> 容貌/ようぼう:名1
# 格フレームid -> 違い無い/ちがいない:形1 格タイプ=ガ: 格表層=こと / 格タイプ=修飾: 格表層=明らかに / 格タイプ=ニ: 格表層=欠陥 /
# 格フレームid -> 荒れる/あれる+果てる/はてる:動1 格タイプ=ガ: 格表層=丘 /
# 格フレームid -> 無い/ない:形25 格タイプ=ガ: 格表層=頭髪 / 格タイプ=修飾: 格表層=全然 / 格タイプ=ニ: 格表層=様 / 格タイプ=ガ２: 格表層=人間 /
# 格フレームid -> 知る/しる~テ形+いる/いる:動4 格タイプ=ガ: 格表層=俺 / 格タイプ=ヲ: 格表層=人間 /
# 格フレームid -> 踏む/ふむ+付ける/つける+られる/られる:動5 格タイプ=ガ: 格表層=畑 /
# 格フレームid -> 蛙/かえる:判0
# 格フレームid -> 潰れる/つぶれる~テ形+いる/いる:動2 格タイプ=ガ: 格表層=鼻 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 恥ずかしい/はずかしい:形16 格タイプ=ガ: 格表層=こと / 格タイプ=修飾: 格表層=甚だ / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 確かだ/たしかだ:形4 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 無くなる/なくなる:動6 格タイプ=ガ: 格表層=鼻 / 格タイプ=外の関係: 格表層=病 / 格タイプ=修飾: 格表層=全然 /
# 格フレームid -> 射る/いる:動2 格タイプ=ガ: 格表層=人 / 格タイプ=ヲ: 格表層=男 / 格タイプ=ニ: 格表層=島 / 格タイプ=修飾: 格表層=しかし /
# 格フレームid -> 足る/たる:動0
# 格フレームid -> 知る/しる:動1 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 苦/く:判5 格タイプ=ガ: 格表層=こと / 格タイプ=ガ２: 格表層=男 /
# 格フレームid -> 酷い/酷い:形18 格タイプ=ガ: 格表層=病 /
# 格フレームid -> 軽い/かるい:形1 格タイプ=ガ: 格表層=方 /
# 格フレームid -> 良い/よい:形1 格タイプ=ガ: 格表層=方 / 格タイプ=修飾: 格表層=やはり / 格タイプ=デ: 格表層=男 /
# 格フレームid -> 直射/ちょくしゃ:名1
# 格フレームid -> 扱き使う/こきつかう+れる/れる:動1 格タイプ=デ: 格表層=下 /
# 格フレームid -> する/する:動5 格タイプ=ヲ: 格表層=午睡 / 格タイプ=デ: 格表層=蔭 / 格タイプ=外の関係: 格表層=方 /
# 格フレームid -> 快い/こころよい:形7 格タイプ=ガ: 格表層=方 / 格タイプ=修飾: 格表層=だが /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 賢い/かしこい:形4 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 祈る/いのる:動11 格タイプ=ガ: 格表層=男 / 格タイプ=時間: 格表層=時 / 格タイプ=ニ: 格表層=神々 /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 減じる/げんじる:動5 格タイプ=ヲ: 格表層=どちら /
# 格フレームid -> 余りだ/あまりだ:形0
# 格フレームid -> 張る/はる:動1 格タイプ=ガ: 格表層=願 / 格タイプ=ヲ: 格表層=慾 / 格タイプ=修飾: 格表層=もし /
# 格フレームid -> 卒/そつ:判0
# 格フレームid -> 供える/そなえる:動1 格タイプ=ヲ: 格表層=芋 /
# 格フレームid -> 祈る/いのる:動11 格タイプ=ガ: 格表層=彼 / 格タイプ=時間: 格表層=祠 /
# 格フレームid -> 祠/祠:判0 格タイプ=ガ: 格表層=の /
# 格フレームid -> 有力だ/ゆうりょくだ:形10 格タイプ=ガ: 格表層=神 / 格タイプ=修飾: 格表層=共に /
# 格フレームid -> する/する:動20 格タイプ=ト: 格表層=神 /
# 格フレームid -> 聞こえる/きこえる~テ形+いる/いる:動1 格タイプ=ガ: 格表層=神 /
# 格フレームid -> 供える/そなえる+られる/られる:動4 格タイプ=ガ: 格表層=神 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 無い/ない:形93 格タイプ=ガ: 格表層=こと / 格タイプ=修飾: 格表層=殆ど / 格タイプ=デ: 格表層=間 /
# 格フレームid -> 御機嫌/ごきげんa:名1
# 格フレームid -> 取る/とる:動8 格タイプ=ヲ: 格表層=御機嫌 /
# 格フレームid -> する/する:動5 格タイプ=ヲ: 格表層=祟 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 分かる/わかる~テ形+いる/いる:動1 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 反する/はんする:動1 格タイプ=ニ: 格表層=之 /
# 格フレームid -> 祭る/まつる+れる/れる:動1 格タイプ=修飾: 格表層=常に / 格タイプ=ニ: 格表層=重 /
# 格フレームid -> 供える/そなえる+られる/られる:動1 格タイプ=ガ: 格表層=神 /
# 格フレームid -> 生ずる/しょうずる:動5 格タイプ=ヲ: 格表層=暴風, 海嘯, 病 / 格タイプ=カラ: 格表層=怒 / 格タイプ=修飾: 格表層=皆 /
# 格フレームid -> 有る/ある:動179 格タイプ=ガ: 格表層=力 / 格タイプ=外の関係: 格表層=蟹, 蚯蚓 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 祈願/きがん:名1
# 格フレームid -> 聞き入れる/ききいれる:動2 格タイプ=ガ: 格表層=蟹, 蚯蚓 / 格タイプ=ヲ: 格表層=祈願 /
# 格フレームid -> 暫く/しばらく:動3 格タイプ=ガ: 格表層=聞入れた / 格タイプ=修飾: 格表層=とにかく / 格タイプ=カラ: 格表層=それ /
# 格フレームid -> 妙だ/みょうだ:形4 格タイプ=ガ: 格表層=夢 /
# 格フレームid -> 見る/みる:動4 格タイプ=ガ: 格表層=男 / 格タイプ=ヲ: 格表層=夢 / 格タイプ=時間: 格表層=晩 / 格タイプ=修飾: 格表層=さて /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 鳴る/なる~テ形+いる/いる:動4 格タイプ=ガ: 格表層=僕 / 格タイプ=修飾: 格表層=何時の間にか / 格タイプ=デ: 格表層=中 / 格タイプ=ニ: 格表層=長老 /
# 格フレームid -> 座る/すわる~テ形+いる/いる:動4 格タイプ=ガ: 格表層=彼 / 格タイプ=ガ２: 格表層=中央, 正座 /
# 格フレームid -> 居る/いる:動15 格タイプ=ガ: 格表層=家長 / 格タイプ=外の関係: 格表層=正座 /
# 格フレームid -> 正座/せいざ:判1 格タイプ=ガ: 格表層=の /
# 格フレームid -> する/する:動1 格タイプ=ト: 格表層=々 /
# 格フレームid -> 従う/したがう:動4 格タイプ=ガ: 格表層=人々 / 格タイプ=修飾: 格表層=皆 / 格タイプ=ニ: 格表層=言葉 /
# 格フレームid -> 損ねる/そこねる:動1 格タイプ=ヲ: 格表層=機嫌 /
# 格フレームid -> する/する:動1 格タイプ=ト: 格表層=焉 /
# 格フレームid -> 懼れる/懼れる:動0 格タイプ=ガ: 格表層=もの /
# 格フレームid -> もの/もの:判0
# 格フレームid -> 出る/でる:動1 格タイプ=修飾: 格表層=もの /
# 格フレームid -> 有る/ある:動1 格タイプ=ト: 格表層=損ね /
# 格フレームid -> 有る/ある:動3 格タイプ=ガ: 格表層=妻 / 格タイプ=ニ: 格表層=彼 /
# 格フレームid -> 食事/しょくじ:名1
# 格フレームid -> 支度/したく:名1
# 格フレームid -> 忙しい/いそがしい:形2 格タイプ=ガ: 格表層=女 / 格タイプ=ニ: 格表層=支度 /
# 格フレームid -> 射る/いる:動2 格タイプ=ガ: 格表層=女 / 格タイプ=ヲ: 格表層=大勢 /
# 格フレームid -> 出す/だす+れる/れる:動1 格タイプ=ガ: 格表層=食卓 / 格タイプ=時間: 格表層=前 /
# 格フレームid -> 茹だる/ゆだる:動2 格タイプ=ガ: 格表層=坊 / 格タイプ=ニ: 格表層=赤 /
# 格フレームid -> 積む/つむ+れる/れる~テ形+いる/いる:動5 格タイプ=ガ: 格表層=卵 / 格タイプ=ニ: 格表層=上 / 格タイプ=ト: 格表層=山 /
# 格フレームid -> 意外だ/いがいだ:形0
# 格フレームid -> 驚く/おどろく:動20 格タイプ=ガ: 格表層=彼 / 格タイプ=修飾: 格表層=意外に /
# 格フレームid -> 夢/ゆめ:判0
# 格フレームid -> 疑う/うたがう:動3 格タイプ=ト: 格表層=夢 /
# 格フレームid -> 不安だ/ふあんだ:形0
# 格フレームid -> 仕方が無い/しかたがない:形0 格タイプ=修飾: 格表層=不安で /
# 格フレームid -> 醒める/醒める:動1 格タイプ=ガ: 格表層=目 / 格タイプ=時間: 格表層=翌朝 /
# 格フレームid -> 破れる/やぶれる:動1 格タイプ=ガ: 格表層=屋根 / 格タイプ=修飾: 格表層=やはり /
# 格フレームid -> 歪む/ゆがむ:動1 格タイプ=ガ: 格表層=柱 / 格タイプ=外の関係: 格表層=何時も /
# 格フレームid -> 寝る/ねる~テ形+いる/いる:動8 格タイプ=ガ: 格表層=彼 / 格タイプ=ニ: 格表層=隅 /
# 格フレームid -> 珍しい/めずらしい:形0
# 格フレームid -> 鳴く/なく:動1 格タイプ=ガ: 格表層=鳥 / 格タイプ=外の関係: 格表層=音 /
# 格フレームid -> 気付く/きづく:動1 格タイプ=ニ: 格表層=音 /
# 格フレームid -> 寝る/ねる+過ごす/すごす:動5 格タイプ=時間: 格表層=朝 /
# 格フレームid -> 酷い/酷い:形0
# 格フレームid -> 叩く/たたく+れる/れる:動4 格タイプ=修飾: 格表層=酷く / 格タイプ=ニ: 格表層=人 /
# 格フレームid -> 鳴る/なる:動1 格タイプ=時間: 格表層=夜 / 格タイプ=デ: 格表層=中 / 格タイプ=ニ: 格表層=彼, 長老 /
# 格フレームid -> 驚く/おどろく:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=時間: 格表層=今度 /
# 格フレームid -> 命令/めいれい:動3 格タイプ=ガ: 格表層=言葉 / 格タイプ=ニ: 格表層=僕 /
# 格フレームid -> 横柄だ/おうへいだ:動0 格タイプ=ガ: 格表層=言葉 /
# 格フレームid -> 堆/堆:形
# 格フレームid -> 載る/のる~テ形+いる/いる:動7 格タイプ=ガ: 格表層=肴 / 格タイプ=修飾: 格表層=堆 / 格タイプ=時間: 格表層=今度 / 格タイプ=ニ: 格表層=食卓 /
# 格フレームid -> 逞しい/逞しい:形4 格タイプ=ガ: 格表層=申し分 /
# 格フレームid -> 無い/ない:形25 格タイプ=ガ: 格表層=申し分 / 格タイプ=ガ２: 格表層=美人 /
# 格フレームid -> 美人/びじん:判4 格タイプ=ガ: 格表層=妻 /
# 格フレームid -> 編む/あむ:動5 格タイプ=ヲ: 格表層=蓙 / 格タイプ=デ: 格表層=葉 /
# 格フレームid -> 新しい/あたらしい:形3 格タイプ=ガ: 格表層=蓙 /
# 格フレームid -> 冷たい/つめたい:形0
# 格フレームid -> よろしい/よろしい:形5 格タイプ=ガ: 格表層=心地 / 格タイプ=修飾: 格表層=誠に /
# 格フレームid -> 成る/なる:動1 格タイプ=時間: 格表層=朝 /
# 格フレームid -> 依然たる/いぜんたる:動
# 格フレームid -> 無い/ない:形38 格タイプ=ガ: 格表層=汚 / 格タイプ=修飾: 格表層=依然と / 格タイプ=ガ２: 格表層=舎 /
# 格フレームid -> 増す/ます:動54 格タイプ=ガ: 格表層=醒 / 格タイプ=ヲ: 格表層=目 / 格タイプ=デ: 格表層=中 / 格タイプ=修飾: 格表層=しかし /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 追う/おう:動0
# 格フレームid -> 使う/つかう+れる/れる:動11 格タイプ=ニ: 格表層=労働 /
# 格フレームid -> する/する:動1 格タイプ=ト: 格表層=食物 /
# 格フレームid -> 与える/あたえる+られる/られる:動1 格タイプ=外の関係: 格表層=こと / 格タイプ=ト: 格表層=尻尾, あら /
# 格フレームid -> 通り/どおり:判1 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 続く/つづく:動4 格タイプ=時間: 格表層=毎晩 / 格タイプ=カラ: 格表層=それ /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 成る/なる:動1 格タイプ=ガ: 格表層=僕 / 格タイプ=時間: 格表層=晩, 晩 / 格タイプ=デ: 格表層=中 / 格タイプ=ニ: 格表層=長老 /
# 格フレームid -> つく/つく~テ形+来る/くる:動3 格タイプ=ガ: 格表層=長老 / 格タイプ=修飾: 格表層=次第に / 格タイプ=ニ: 格表層=板 /
# 格フレームid -> 御馳走/ごちそう:名1
# 格フレームid -> 見る/みる:動1 格タイプ=ヲ: 格表層=御馳走 /
# 格フレームid -> 頃/ころ:判0 格タイプ=修飾: 格表層=もう /
# 格フレームid -> ガツガツ/がつがつ:動1 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 無い/ない:形1 格タイプ=ガ: 格表層=こと /
# 格フレームid -> する/する:動113 格タイプ=ヲ: 格表層=争い / 格タイプ=時間: 格表層=間 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 度重なる/たびかさなる:動0 格タイプ=ガ: 格表層=こと /
# 格フレームid -> 手出し/てだし:名1
# 格フレームid -> 出来る/できる:動25 格タイプ=ガ: 格表層=手出し / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 知る/しる:動1 格タイプ=ヲ: 格表層=こと / 格タイプ=ニ: 格表層=女 /
# 格フレームid -> 久しい/ひさしい:動0 格タイプ=ガ: 格表層=知って /
# 格フレームid -> 使/使:動0 格タイプ=ヲ: 格表層=島民 /
# 格フレームid -> 作る/つくる+せる/せる:動1 格タイプ=ヲ: 格表層=庫 /
# 格フレームid -> 執り行う/とりおこなう:動2 格タイプ=ヲ: 格表層=祭祀 /
# 格フレームid -> 導く/みちびく+れる/れる:動2 格タイプ=ニ: 格表層=司祭 /
# 格フレームid -> 進む/すすむ:動3 格タイプ=ガ: 格表層=彼 / 格タイプ=ニ: 格表層=神前 /
# 格フレームid -> 敷く/しく:動1 格タイプ=ガ: 格表層=共 / 格タイプ=ヲ: 格表層=斉 / 格タイプ=時間: 格表層=英雄 /
# 格フレームid -> 再来/さいらい:判0
# 格フレームid -> 驚嘆/きょうたん:動2 格タイプ=ニ: 格表層=さ / 格タイプ=ト: 格表層=再来 /
# 格フレームid -> 仕える/つかえる:動4 格タイプ=ガ: 格表層=僕 / 格タイプ=ニ: 格表層=彼 /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=主人 / 格タイプ=時間: 格表層=長老 /
# 格フレームid -> 居る/いる:動15 格タイプ=ガ: 格表層=男 / 格タイプ=ニ: 格表層=人 / 格タイプ=ト: 格表層=長老 /
# 格フレームid -> 怖れる/怖れる:動7 格タイプ=ヲ: 格表層=彼 / 格タイプ=外の関係: 格表層=様 /
# 格フレームid -> 言う/いう:動3 格タイプ=ト: 格表層=様 /
# 格フレームid -> おかしい/おかしい:形1 格タイプ=ガ: 格表層=位 /
# 格フレームid -> くらい/くらい:判0
# 格フレームid -> 似る/にる:動2 格タイプ=ガ: 格表層=彼 / 格タイプ=時間: 格表層=僕 / 格タイプ=ニ: 格表層=長老 /
# 格フレームid -> 酷い/酷い:形1 格タイプ=ガ: 格表層=労働 / 格タイプ=修飾: 格表層=一番 / 格タイプ=ニ: 格表層=僕 /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 言い付ける/いいつける:動3 格タイプ=ガ: 格表層=それ / 格タイプ=ヲ: 格表層=労働 / 格タイプ=ニ: 格表層=さ /
# 格フレームid -> する/する+せる/せる:動1 格タイプ=ガ: 格表層=漁 /
# 格フレームid -> 採る/とる:動11 格タイプ=ヲ: 格表層=蜜 /
# 格フレームid -> 乗る/のる:動1 格タイプ=ガ: 格表層=舟 /
# 格フレームid -> 当たる/あたる:動14 格タイプ=ガ: 格表層=から / 格タイプ=ニ: 格表層=途 /
# 格フレームid -> 泳ぐ/およぐ:動5 格タイプ=ガ: 格表層=鱶 / 格タイプ=ヲ: 格表層=水中 / 格タイプ=カラ: 格表層=独木舟 /
# 格フレームid -> 跳ぶ/とぶ:動2 格タイプ=ガ: 格表層=から / 格タイプ=ヲ: 格表層=僕 / 格タイプ=ニ: 格表層=水中 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 慌てる/あわてる:動1 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 畏れる/畏れる:動3 格タイプ=外の関係: 格表層=様 /
# 格フレームid -> 痛い/いたい:形0
# 格フレームid -> 満足/まんぞく:名1
# 格フレームid -> 与える/あたえる:動2 格タイプ=ガ: 格表層=様 / 格タイプ=ヲ: 格表層=満足 / 格タイプ=ニ: 格表層=彼 /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 苛酷だ/かこくだ:形1 格タイプ=ガ: 格表層=待遇 /
# 格フレームid -> 待遇/たいぐう:名0
# 格フレームid -> 漏らす/もらす:動5 格タイプ=ガ: 格表層=労働 / 格タイプ=ヲ: 格表層=嘆声 / 格タイプ=ニ: 格表層=彼 /
# 格フレームid -> 賢い/かしこい:形4 格タイプ=ガ: 格表層=諦め /
# 格フレームid -> 言う/いう:動2 格タイプ=ヲ: 格表層=言葉 / 格タイプ=ニ: 格表層=自ら /
# 格フレームid -> 聞く/きく+せる/せる:動5 格タイプ=ヲ: 格表層=必要 /
# 格フレームid -> 無くなる/なくなる:動2 格タイプ=ガ: 格表層=必要 /
# 格フレームid -> 思う/おもう:動1
# 格フレームid -> 労/ろう:判0 格タイプ=ガ: 格表層=数 /
# 格フレームid -> 数/すう:名0
# 格フレームid -> 辛い/つらい:形12 格タイプ=ガ: 格表層=仕事 /
# 格フレームid -> 仕事/しごと:名1 格タイプ=ノ: 格表層=日 /
# 格フレームid -> 疲れる/つかれる+果てる/はてる:動8 格タイプ=ニ: 格表層=仕事 /
# 格フレームid -> 気だ/げだ:形1 格タイプ=ガ: 格表層=微笑 / 格タイプ=修飾: 格表層=世にも /
# 格フレームid -> 微笑/びしょう:名1
# 格フレームid -> 浮かべる/うかべる:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=微笑 /
# 格フレームid -> 見る/みる:動4 格タイプ=ヲ: 格表層=夢 / 格タイプ=外の関係: 格表層=ため /
# 格フレームid -> 折れる/おれる:動14 格タイプ=ガ: 格表層=柱 / 格タイプ=外の関係: 格表層=汚 /
# 格フレームid -> 無い/ない:形1 格タイプ=ガ: 格表層=汚 / 格タイプ=ガ２: 格表層=寝床 /
# 格フレームid -> 急ぐ/いそぐ:動4 格タイプ=修飾: 格表層=ため / 格タイプ=ヘ: 格表層=寝床 /
# 格フレームid -> 言う/いう:動0 格タイプ=修飾: 格表層=そう /
# 格フレームid -> 摂る/とる:動2 格タイプ=ヲ: 格表層=美食 / 格タイプ=デ: 格表層=中 /
# 格フレームid -> 美食/びしょく:名1
# 格フレームid -> 所為/所為:判0
# 格フレームid -> 着る/きる:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=所為 / 格タイプ=時間: 格表層=近頃 / 格タイプ=修飾: 格表層=めっきり /
# 格フレームid -> 良い/よい+なる/なる:動1 格タイプ=ガ: 格表層=顔色 / 格タイプ=修飾: 格表層=すっかり /
# 格フレームid -> 何時か/いつか:動0 格タイプ=ガ: 格表層=咳 /
# 格フレームid -> 若返る/わかがえる:動0 格タイプ=修飾: 格表層=見るからに /
# 格フレームid -> 哀れだ/あわれだ:形1 格タイプ=ガ: 格表層=者 / 格タイプ=修飾: 格表層=丁度 /
# 格フレームid -> 醜い/みにくい:形5 格タイプ=ガ: 格表層=者 /
# 格フレームid -> 卯/う:動0 格タイプ=ガ: 格表層=夢 /
# 格フレームid -> 見る/みる+始める/はじめる:動11 格タイプ=ガ: 格表層=僕 / 格タイプ=ヲ: 格表層=夢 / 格タイプ=外の関係: 格表層=頃 /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=主人 / 格タイプ=外の関係: 格表層=め /
# 格フレームid -> 態/態:判1 格タイプ=ガ: 格表層=夢 /
# 格フレームid -> 見る/みる:動4 格タイプ=ガ: 格表層=長老 / 格タイプ=ヲ: 格表層=夢 / 格タイプ=カラ: 格表層=頃 /
# 格フレームid -> 尊い/とうとい:形0
# 格フレームid -> 惨めだ/みじめだ:形1 格タイプ=ガ: 格表層=長老 / 格タイプ=ガ２: 格表層=僕 /
# 格フレームid -> 貧しい/まずしい:形2 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 鳴る/なる:動1 格タイプ=デ: 格表層=中 / 格タイプ=ニ: 格表層=僕 /
# 格フレームid -> 至る/いたる:動21 格タイプ=ガ: 格表層=迄 / 格タイプ=ニ: 格表層=取り, 造り / 格タイプ=カラ: 格表層=作り /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 課する/かする:動3 格タイプ=ガ: 格表層=迄, 労働 / 格タイプ=ニ: 格表層=彼 / 格タイプ=カラ: 格表層=漁 /
# 格フレームid -> 仕事/しごと:名1
# 格フレームid -> 多い/おおい:形29 格タイプ=ガ: 格表層=仕事 / 格タイプ=修飾: 格表層=こう /
# 格フレームid -> 無数だ/むすうだ:形1
# 格フレームid -> 生える/はえる~テ形+いる/いる:動9 格タイプ=ガ: 格表層=手 / 格タイプ=外の関係: 格表層=蚣 / 格タイプ=修飾: 格表層=無数に /
# 格フレームid -> やる/やる+切れる/きれる:動1 格タイプ=デ: 格表層=蚣 /
# 格フレームid -> 思う/おもう+れる/れる:動1 格タイプ=外の関係: 格表層=程 / 格タイプ=ト: 格表層=遣り /
# 格フレームid -> 程/ほど:判0
# 格フレームid -> 言い付ける/いいつける:動3 格タイプ=ガ: 格表層=主人 / 格タイプ=ヲ: 格表層=用 /
# 格フレームid -> 言う/いう:動1 格タイプ=ガ: 格表層=男 / 格タイプ=ト: 格表層=主人 /
# 格フレームid -> 卑しい/いやしい:形6 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 僕/ぼく:判3 格タイプ=ガ: 格表層=筈 /
# 格フレームid -> 男/おとこ:判7 格タイプ=ガ: 格表層=の / 格タイプ=時間: 格表層=昼間 /
# 格フレームid -> ひどい/ひどい:形0
# 格フレームid -> 意地悪だ/いじわるだ:形0
# 格フレームid -> 言う/いう:動2 格タイプ=ヲ: 格表層=無理 / 格タイプ=ヘ: 格表層=次, 次 /
# 格フレームid -> 吸い付く/すいつく:動1 格タイプ=ニ: 格表層=蛸 /
# 格フレームid -> 挟む/はさむ+れる/れる:動2 格タイプ=ヲ: 格表層=足 / 格タイプ=ニ: 格表層=貝 /
# 格フレームid -> 切る/きる+れる/れる:動1 格タイプ=ヲ: 格表層=指 / 格タイプ=ニ: 格表層=鱶 /
# 格フレームid -> 食事/しょくじ:名1
# 格フレームid -> 言う/いう:動16 格タイプ=ト: 格表層=食事 /
# 格フレームid -> 粗/あら:名0
# 格フレームid -> 贅沢だ/ぜいたくだ:形9 格タイプ=ガ: 格表層=蓙 /
# 格フレームid -> 覚ます/さます:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=醒 / 格タイプ=時間: 格表層=毎朝 / 格タイプ=修飾: 格表層=上 / 格タイプ=外の関係: 格表層=時 /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 疲れる/つかれる:動1 格タイプ=ニ: 格表層=労働 /
# 格フレームid -> 痛む/いたむ:動2 格タイプ=ガ: 格表層=節々 / 格タイプ=修飾: 格表層=ズキズキ / 格タイプ=時間: 格表層=時 /
# 格フレームid -> 言う/いう:動1 格タイプ=ガ: 格表層=う / 格タイプ=外の関係: 格表層=夢 /
# 格フレームid -> 見る/みる~テ形+いる/いる:動9 格タイプ=ヲ: 格表層=夢 / 格タイプ=時間: 格表層=毎晩 / 格タイプ=外の関係: 格表層=中 /
# 格フレームid -> 失せる/うせる:動1 格タイプ=ガ: 格表層=気 / 格タイプ=修飾: 格表層=次第に / 格タイプ=カラ: 格表層=身体 /
# 格フレームid -> 出る/でる:動0
# 格フレームid -> 張る/はる:動7 格タイプ=ガ: 格表層=腹 /
# 格フレームid -> しぼむ/しぼむ:動0 格タイプ=ガ: 格表層=腹 / 格タイプ=ニ: 格表層=中 /
# 格フレームid -> 痩せる/やせる:動4 格タイプ=ガ: 格表層=誰 / 格タイプ=外の関係: 格表層=外 / 格タイプ=デ: 格表層=尻尾, あら / 格タイプ=修飾: 格表層=実際 /
# 格フレームid -> 無い/ない:形1 格タイプ=ガ: 格表層=外 /
# 格フレームid -> 欠/けつ:動0 格タイプ=ガ: 格表層=月 /
# 格フレームid -> 惨めだ/みじめだ:形0
# 格フレームid -> 衰える/おとろえる:動8 格タイプ=ガ: 格表層=長老 / 格タイプ=修飾: 格表層=みじめに / 格タイプ=時間: 格表層=中 /
# 格フレームid -> 嫌だ/いやだ:形1 格タイプ=ガ: 格表層=咳 /
# 格フレームid -> する/する:動36 格タイプ=ヲ: 格表層=咳 /
# 格フレームid -> 立てる/たてる:動6 格タイプ=ガ: 格表層=長老 / 格タイプ=ヲ: 格表層=腹 /
# 格フレームid -> 呼ぶ/よぶ+付ける/つける:動1 格タイプ=ヲ: 格表層=僕 / 格タイプ=ニ: 格表層=竟 /
# 格フレームid -> 虐げる/しいたげる:動0 格タイプ=ガ: 格表層=男 / 格タイプ=ヲ: 格表層=己 /
# 格フレームid -> 憎む/にくむ:動1 格タイプ=ヲ: 格表層=男 /
# 格フレームid -> 思い切る/おもいきる:動0
# 格フレームid -> 罰す/ばっす:動0 格タイプ=ヲ: 格表層=男 /
# 格フレームid -> 決心/けっしん:動1 格タイプ=ト: 格表層=思いきり, 罰して /
# 格フレームid -> 現れる/あらわれる:動3 格タイプ=ガ: 格表層=所 / 格タイプ=時間: 格表層=僕 / 格タイプ=ニ: 格表層=目の前 /
# 格フレームid -> 咳/せき:動0 格タイプ=ガ: 格表層=て /
# 格フレームid -> おどおど/おどおど:動0 格タイプ=ヲ: 格表層=咳 /
# 格フレームid -> 畏れる/畏れる:動1 格タイプ=ト: 格表層=おどおど /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=者 /
# 格フレームid -> 者/しゃ:判2 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> する/する:動0 格タイプ=修飾: 格表層=生き生き /
# 格フレームid -> 見える/みえる:動2 格タイプ=ガ: 格表層=り, 顔色 / 格タイプ=修飾: 格表層=何時の間にか / 格タイプ=ニ: 格表層=杯 /
# 格フレームid -> 見る/みる:動47 格タイプ=ガ: 格表層=態度 / 格タイプ=ヲ: 格表層=て, 言葉 / 格タイプ=ニ: 格表層=自信 / 格タイプ=修飾: 格表層=如何にも /
# 格フレームid -> 甘んずる/あまんずる:動0 格タイプ=ガ: 格表層=もの / 格タイプ=ニ: 格表層=使 /
# 格フレームid -> 思う/おもう+れる/れる:動1 格タイプ=修飾: 格表層=到底 / 格タイプ=ニ: 格表層=それ / 格タイプ=ト: 格表層=もの /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=揚 / 格タイプ=外の関係: 格表層=其 /
# 格フレームid -> 微笑/びしょう:名1
# 格フレームid -> 見る/みる:動2 格タイプ=ヲ: 格表層=微笑 /
# 格フレームid -> 圧倒/あっとう+する/する+れる/れる:動2 格タイプ=ガ: 格表層=長老 / 格タイプ=修飾: 格表層=すっかり / 格タイプ=デ: 格表層=見た / 格タイプ=ニ: 格表層=感 /
# 格フレームid -> 了/了:判
# 格フレームid -> 蘇る/よみがえる~テ形+来る/くる:動1 格タイプ=ガ: 格表層=迄 /
# 格フレームid -> 脅す/おどす:動2 格タイプ=ヲ: 格表層=彼 /
# 格フレームid -> 現実/げんじつ:判2 格タイプ=ガ: 格表層=何れ /
# 格フレームid -> 掠める/掠める:動1 格タイプ=ガ: 格表層=疑 / 格タイプ=ヲ: 格表層=頭 / 格タイプ=ト: 格表層=チラ /
# 格フレームid -> 痩せ衰える/やせおとろえる:動0 格タイプ=ガ: 格表層=自分 /
# 格フレームid -> 自分/じぶん:判4 格タイプ=ガ: 格表層=者 /
# 格フレームid -> する/する:動36 格タイプ=ヲ: 格表層=咳 / 格タイプ=修飾: 格表層=今更 /
# 格フレームid -> 堂々たる/どうどうたる:形1 格タイプ=ガ: 格表層=男 /
# 格フレームid -> 叱る/しかる+付ける/つける:動1 格タイプ=ガ: 格表層=者 / 格タイプ=ヲ: 格表層=男 /
# 格フレームid -> 寄る/よる:動1 格タイプ=ガ: 格表層=思い / 格タイプ=ト: 格表層=叱り /
# 格フレームid -> 予期/よき:動1 格タイプ=ガ: 格表層=自分 / 格タイプ=外の関係: 格表層=程 /
# 格フレームid -> 懃/懃:判0 格タイプ=ガ: 格表層=言葉 /
# 格フレームid -> 言葉/ことば:判0
# 格フレームid -> 向う/向う:動1 格タイプ=ニ: 格表層=男 /
# 格フレームid -> 健康/けんこうa:名0
# 格フレームid -> 回復/かいふく:動32 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=健康 / 格タイプ=外の関係: 格表層=次第 /
# 格フレームid -> 尋ねる/たずねる:動3 格タイプ=ガ: 格表層=長老 / 格タイプ=ヲ: 格表層=次第 /
# 格フレームid -> 詳しい/くわしい:形0
# 格フレームid -> 語る/かたる:動4 格タイプ=ガ: 格表層=男 / 格タイプ=ヲ: 格表層=こと /
# 格フレームid -> 美食/びしょく:名1
# 格フレームid -> 着る/きる:動1 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=※ / 格タイプ=時間: 格表層=夜毎 / 格タイプ=ニ: 格表層=美食 / 格タイプ=修飾: 格表層=如何に /
# 格フレームid -> 足る/たる:動0
# 格フレームid -> 貸す/かす:動5 格タイプ=修飾: 格表層=如何に / 格タイプ=ニ: 格表層=僕 /
# 格フレームid -> 好く/すく+れる/れる:動0
# 格フレームid -> 快い/こころよい:形8 格タイプ=ガ: 格表層=逸 /
# 格フレームid -> 染む/しむ:動5 格タイプ=ガ: 格表層=娯 / 格タイプ=ヲ: 格表層=逸 /
# 格フレームid -> 酔う/よう:動0 格タイプ=修飾: 格表層=如何に /
# 格フレームid -> 楽しみ/たのしみa:名1
# 格フレームid -> 味わう/あじわう:動4 格タイプ=ヲ: 格表層=楽しみ /
# 格フレームid -> 話/はなし:名1
# 格フレームid -> 聞く/きく+終わる/おわる:動1 格タイプ=ヲ: 格表層=話 /
# 格フレームid -> 驚く/おどろく:動2 格タイプ=ガ: 格表層=長老 / 格タイプ=修飾: 格表層=大いに /
# 格フレームid -> 斯/斯:形
# 格フレームid -> 驚く/おどろく:動2 格タイプ=ガ: 格表層=一致 / 格タイプ=修飾: 格表層=斯 /
# 格フレームid -> 一致/いっち:名1
# 格フレームid -> 基づく/もとづく:動12 格タイプ=ガ: 格表層=一致 / 格タイプ=ニ: 格表層=何 /
# 格フレームid -> 醒める/醒める:動1 格タイプ=ガ: 格表層=栄養 /
# 格フレームid -> 足る/たる:動1 格タイプ=ガ: 格表層=世界 /
# 格フレームid -> 及ぼす/およぼす:動1 格タイプ=ガ: 格表層=く, 影響, 甚だしい / 格タイプ=ニ: 格表層=肉体 /
# 格フレームid -> 影響/えいきょう:名1
# 格フレームid -> 区/く:判0
# 格フレームid -> 甚だしい/はなはだしい:形0
# 格フレームid -> 同じだ/おなじだ:形9 格タイプ=ト: 格表層=世界 /
# 格フレームid -> 現実/げんじつ:判2 格タイプ=ガ: 格表層=それ / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 疑う/うたがう:動1 格タイプ=ガ: 格表層=こと / 格タイプ=ヲ: 格表層=早 / 格タイプ=外の関係: 格表層=余地 /
# 格フレームid -> 無い/ない:形15 格タイプ=ガ: 格表層=余地 /
# 格フレームid -> 忍ぶ/しのぶ:動2 格タイプ=ガ: 格表層=彼 / 格タイプ=ヲ: 格表層=恥 /
# 格フレームid -> 告げる/つげる:動7 格タイプ=ガ: 格表層=己 / 格タイプ=ヲ: 格表層=こと / 格タイプ=ニ: 格表層=男 /
# 格フレームid -> 労働/ろうどう:名1
# 格フレームid -> 強いる/しいる+られる/られる:動5 格タイプ=ガ: 格表層=自分 / 格タイプ=ヲ: 格表層=労働 / 格タイプ=時間: 格表層=夜毎 / 格タイプ=修飾: 格表層=如何に /
# 格フレームid -> 我慢/がまん:動4 格タイプ=修飾: 格表層=如何に / 格タイプ=デ: 格表層=尻尾, あら /
# 格フレームid -> 聞く/きく:動4 格タイプ=ガ: 格表層=男 / 格タイプ=ヲ: 格表層=それ /
# 格フレームid -> 驚く/おどろく:動0 格タイプ=修飾: 格表層=一向に /
# 格フレームid -> 有る/ある:動0 格タイプ=修飾: 格表層=さも /
# 格フレームid -> 言う/いう:動1 格タイプ=外の関係: 格表層=顔付 / 格タイプ=ト: 格表層=あろう /
# 格フレームid -> 疾/疾:形
# 格フレームid -> 似る/にる:動0
# 格フレームid -> 知る/しる~テ形+いる/いる:動2 格タイプ=ヲ: 格表層=事 / 格タイプ=修飾: 格表層=疾 /
# 格フレームid -> 聞く/きく:動2 格タイプ=ヲ: 格表層=事 / 格タイプ=デ: 格表層=顔付 /
# 格フレームid -> 満足気だ/まんぞくげだ:形1 格タイプ=ガ: 格表層=微笑 /
# 格フレームid -> 微笑/びしょう:名1
# 格フレームid -> 湛える/たたえる:動1 格タイプ=ヲ: 格表層=微笑 /
# 格フレームid -> 首肯く/うなずく:動1 格タイプ=ニ: 格表層=揚 /
# 格フレームid -> する/する:動6 格タイプ=ガ: 格表層=満腹 / 格タイプ=ニ: 格表層=中 /
# 格フレームid -> 眠る/ねむる:動16 格タイプ=ガ: 格表層=鰻 / 格タイプ=修飾: 格表層=誠に /
# 格フレームid -> 鰻/うなぎ:判1 格タイプ=ガ: 格表層=顔 /
# 格フレームid -> 幸福だ/こうふくだ:形0
# 格フレームid -> 輝く/かがやく~テ形+いる/いる:動2 格タイプ=ガ: 格表層=至上 / 格タイプ=修飾: 格表層=幸福に /
# 格フレームid -> 現実/げんじつ:判7 格タイプ=ガ: 格表層=夢 / 格タイプ=修飾: 格表層=一層 / 格タイプ=ヨリ: 格表層=世界 / 格タイプ=外の関係: 格表層=こと /
# 格フレームid -> 確信/かくしん+する/する~テ形+いる/いる:動1 格タイプ=ガ: 格表層=男 / 格タイプ=修飾: 格表層=既に /
# 格フレームid -> 吐く/はく:動1 格タイプ=ヲ: 格表層=溜息 /
# 格フレームid -> 哀れだ/あわれだ:形3 格タイプ=ガ: 格表層=め /
# 格フレームid -> 貧しい/まずしい:形0
# 格フレームid -> 賢い/かしこい:形4 格タイプ=ガ: 格表層=僕 /
# 格フレームid -> 嫉む/そねむ:動0 格タイプ=ヲ: 格表層=顔 /
# 格フレームid -> 眺める/ながめる:動3 格タイプ=ガ: 格表層=主人 / 格タイプ=ニ: 格表層=げ /
# 格フレームid -> 右/みぎ:名1
# 格フレームid -> 無い/ない:形0
# 格フレームid -> 昔話/むかしばなし:判1 格タイプ=ガ: 格表層=右 / 格タイプ=修飾: 格表層=世に / 格タイプ=時間: 格表層=今 /
# 格フレームid -> 前/まえ:名0
# 格フレームid -> 陥没/かんぼつ:動1 格タイプ=修飾: 格表層=突然 / 格タイプ=ニ: 格表層=海底 /
# 格フレームid -> 了/了:判0 格タイプ=ガ: 格表層=島 /
# 格フレームid -> 見る/みる:動4 格タイプ=ガ: 格表層=来, 合わせ / 格タイプ=ヲ: 格表層=夢 / 格タイプ=時間: 格表層=男 /
# 格フレームid -> 居る/いる:動22 格タイプ=ガ: 格表層=男 / 格タイプ=ニ: 格表層=中 /
# 格フレームid -> こと/こと:判0

# %%
# TODO 格が特定のNamed entity/人/場所であることを判定したい
# TODO 基本句idで紐付けをして、Named entity/人/場所
# TODO CRFで判定した情報とJumanが判定した情報は別にしておきたい。階層構造にしておく人-crf, 人-jumanなど
